# %% [markdown]
# ![image info](https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/images/banner_1.png)

# %% [markdown]
# # Taller: Análisis de sentimientos y técnicas de NLP
#
# En este taller podrán poner en práctica sus conocimientos sobre las diferentes técnicas para el procesamiento de lenguaje natural. El taller está constituido por 5 puntos, en los cuales deberan seguir las intrucciones de cada numeral para su desarrollo.

# %% [markdown]
# ## Datos predicción sentimientos de viajeros en Twitter
#
# En este taller se usará el conjunto de datos de sentimientos sobre distintas aerolíneas de EE.UU. provenientes de Twitter. Cada observación contiene si el sentimiento de los tweets es positivo, neutral o negativo teniendo en cuenta distintas variables como aerolínea y las razones de los sentimientos negativos (como "retraso en el vuelo" o "servicio grosero"). El objetivo es predecir el sentimiento asociado a cada tweet. Para más detalles pueden visitar el siguiente enlace: [datos](https://www.kaggle.com/crowdflower/twitter-airline-sentiment).

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importación de librerías
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# Lectura de la información de archivo .zip
tweets = pd.read_csv('https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/datasets/Tweets.zip', index_col=0)

# Visualización dataset
tweets.head()
# Out:
#                    airline_sentiment  airline_sentiment_confidence  \
# tweet_id
# 570306133677760513           neutral                        1.0000
# 570301130888122368          positive                        0.3486
# 570301083672813571           neutral                        0.6837
# 570301031407624196          negative                        1.0000
# 570300817074462722          negative                        1.0000
#
#                    negativereason  negativereason_confidence         airline  \
# tweet_id
# 570306133677760513            NaN                        NaN  Virgin America
# 570301130888122368            NaN                     0.0000  Virgin America
# 570301083672813571            NaN                        NaN  Virgin America
# 570301031407624196     Bad Flight                     0.7033  Virgin America
# 570300817074462722     Can't Tell                     1.0000  Virgin America
#
#                    airline_sentiment_gold        name negativereason_gold  \
# tweet_id
# 570306133677760513                    NaN     cairdin                 NaN
# 570301130888122368                    NaN    jnardino                 NaN
# 570301083672813571                    NaN  yvonnalynn                 NaN
# 570301031407624196                    NaN    jnardino                 NaN
# 570300817074462722                    NaN    jnardino                 NaN
#
#                     retweet_count  \
# tweet_id
# 570306133677760513              0
# 570301130888122368              0
# 570301083672813571              0
# 570301031407624196              0
# 570300817074462722              0
#
#                                                                  text  \
# tweet_id
# 570306133677760513                @VirginAmerica What @dhepburn said.
# 570301130888122368  @VirginAmerica plus you've added commercials t...
# 570301083672813571  @VirginAmerica I didn't today... Must mean I n...
# 570301031407624196  @VirginAmerica it's really aggressive to blast...
# 570300817074462722  @VirginAmerica and it's a really big bad thing...
#
#                    tweet_coord              tweet_created tweet_location  \
# tweet_id
# 570306133677760513         NaN  2015-02-24 11:35:52 -0800            NaN
# 570301130888122368         NaN  2015-02-24 11:15:59 -0800            NaN
# 570301083672813571         NaN  2015-02-24 11:15:48 -0800      Lets Play
# 570301031407624196         NaN  2015-02-24 11:15:36 -0800            NaN
# 570300817074462722         NaN  2015-02-24 11:14:45 -0800            NaN
#
#                                  user_timezone
# tweet_id
# 570306133677760513  Eastern Time (US & Canada)
# 570301130888122368  Pacific Time (US & Canada)
# 570301083672813571  Central Time (US & Canada)
# 570301031407624196  Pacific Time (US & Canada)
# 570300817074462722  Pacific Time (US & Canada)

# %%
# Impresión tamaño del cojunto de datos
tweets.shape
# Out:
# (14640, 14)

# %% [markdown]
# ### Análisis descriptivo

# %%
# Cuenta de tweets por cada sentimiento
tweets['airline_sentiment'].value_counts()
# Out:
# negative    9178
# neutral     3099
# positive    2363
# Name: airline_sentiment, dtype: int64

# %%
# Cuenta de tweets por cada aerolínea
tweets['airline'].value_counts()
# Out:
# United            3822
# US Airways        2913
# American          2759
# Southwest         2420
# Delta             2222
# Virgin America     504
# Name: airline, dtype: int64

# %%
# Plot con cuenta de tweets por cada aerolínea y sentimiento
pd.crosstab(index = tweets["airline"],columns = tweets["airline_sentiment"]).plot(kind='bar',figsize=(10, 6),alpha=0.5,rot=0,stacked=True,title="Sentiminetos por aerolínea")

# %% [markdown]
# ### Liberias y Variables de interés y predicción

# %%
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.ensemble import RandomForestClassifier
from nltk.stem.snowball import SnowballStemmer
from nltk.stem import WordNetLemmatizer

# %%
# Separación de variables predictoras (X) y de variable de interés (y)
X = tweets['text']
y = tweets['airline_sentiment'].map({'negative':-1,'neutral':0,'positive':1})

# %%
y.values_
# Out:
# tweet_id
# 570306133677760513    0
# 570301130888122368    1
# 570301083672813571    0
# 570301031407624196   -1
# 570300817074462722   -1
#                      ..
# 569587686496825344    1
# 569587371693355008   -1
# 569587242672398336    0
# 569587188687634433   -1
# 569587140490866689    0
# Name: airline_sentiment, Length: 14640, dtype: int64

# %%
# Separación de datos en set de entrenamiento y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ### Punto 1 - Uso de CountVectorizer
#
# En la celda 1 creen un modelo de random forest con la libreria sklearn que prediga el sentimiento de los tweets usando los set de entrenamiento y test definidos anteriormente. Usen la función **CountVectorizer** y presenten el desempeño del modelo con la métrica del acurracy.
#
# Recuerden que el preprocesamiento que se haga sobre los datos de entrenamiento  (*.fit_transform()*) deben ser aplicado al set de test (*.transform()*).

# %%
# Celda 1
vect = CountVectorizer()
X_dtm = vect.fit_transform(X_train)

# %%
temp=X_dtm.todense()

# %%
vect.vocabulary_
# Out:
# {'jetblue': 6206,
#  'of': 7768,
#  'course': 3393,
#  'am': 1680,
#  'americanair': 1695,
#  'complt': 3218,
#  'incompetence': 5893,
#  'on': 7815,
#  'flt': 4790,
#  '295': 508,
#  'lav': 6525,
#  'delay': 3661,
#  'from': 4975,
#  'pln': 8327,
#  'that': 10546,
#  'lnded': 6713,
#  'last': 6503,
#  'nite': 7566,
#  'no': 7580,
#  'internet': 6039,
#  'and': 1729,
#  'poor': 8364,
#  'svc': 10323,
#  'not': 7655,
#  'what': 11670,
#  'expect': 4460,
#  'southwestair': 9955,
#  'flight': 4735,
#  '4968': 846,
#  'n8325d': 7405,
#  'departs': 3705,
#  'mco': 7032,
#  'enroute': 4292,
#  'to': 10724,
#  'no_airport': 7582,
#  'http': 5713,
#  'co': 3090,
#  'fd4snvkiem': 4597,
#  'usairways': 11325,
#  'does': 3962,
#  'anyone': 1798,
#  'your': 11982,
#  'airline': 1584,
#  'know': 6426,
#  'how': 5694,
#  'do': 3953,
#  'their': 10562,
#  'job': 6254,
#  'united': 11192,
#  'want': 11570,
#  'plane': 8290,
#  'dad': 3546,
#  'my': 7375,
#  '386': 664,
#  'dallas': 3556,
#  'jacksonville': 6151,
#  'fl': 4711,
#  'has': 5448,
#  'been': 2231,
#  'cancelled': 2710,
#  'flightled': 4765,
#  'one': 7821,
#  'notified': 7675,
#  'me': 7043,
#  'going': 5215,
#  'it': 6109,
#  'is': 6093,
#  'trying': 10911,
#  'make': 6915,
#  'but': 2616,
#  'probably': 8528,
#  'too': 10757,
#  'late': 6511,
#  'did': 3783,
#  'see': 9515,
#  'an': 1720,
#  'email': 4219,
#  'could': 3375,
#  'call': 2687,
#  'pittsburgh': 8270,
#  'international': 6037,
#  'always': 1674,
#  'look': 6767,
#  'forward': 4907,
#  'jb': 6182,
#  'rt': 9275,
#  'bostongarden': 2449,
#  'looking': 6771,
#  'welcoming': 11644,
#  'you': 11976,
#  'onboard': 7817,
#  'have': 5463,
#  'the': 10550,
#  'ability': 1382,
#  'switch': 10355,
#  'cannot': 2721,
#  'tell': 10486,
#  'where': 11687,
#  'bags': 2127,
#  'are': 1878,
#  'refused': 8921,
#  'boarding': 2403,
#  'with': 11774,
#  'nexus': 7532,
#  'confirmed': 3249,
#  'she': 9632,
#  'should': 9673,
#  'be': 2202,
#  'thank': 10533,
#  'or': 7875,
#  'cud': 3488,
#  'answer': 1774,
#  'here': 5537,
#  '140': 175,
#  'plenty': 8325,
#  'inflight': 5948,
#  'stealing': 10104,
#  'right': 9173,
#  'now': 7688,
#  'amp': 1715,
#  'fa': 4517,
#  'won': 11800,
#  'uncomfortable': 11140,
#  'convo': 3338,
#  'pass': 8083,
#  'roundtrip': 9259,
#  'london': 6759,
#  'delta': 3680,
#  'think': 10598,
#  'will': 11735,
#  'fyi': 5054,
#  'another': 1770,
#  '1k': 340,
#  'just': 6308,
#  'lost': 6786,
#  'moneynotspentonunited': 7275,
#  'unfriendlyskies': 11181,
#  'was': 11582,
#  'hung': 5734,
#  'up': 11267,
#  'by': 2633,
#  'customer': 3509,
#  'service': 9573,
#  'after': 1532,
#  'waiting': 11541,
#  '30': 564,
#  'min': 7183,
#  'hold': 5602,
#  'guess': 5343,
#  'vacation': 11381,
#  'happening': 5420,
#  'website': 11624,
#  'wasn': 11585,
#  'working': 11824,
#  'hey': 5543,
#  'left': 6565,
#  'computer': 3222,
#  'bag': 2120,
#  'inside': 5985,
#  'in': 5861,
#  'filed': 4659,
#  'online': 7832,
#  'report': 9019,
#  'response': 9087,
#  'as': 1916,
#  'already': 1663,
#  'booked': 2425,
#  'can': 2704,
#  'use': 11342,
#  'change': 2872,
#  '200': 363,
#  'fee': 4613,
#  'booking': 2426,
#  'problems': 8531,
#  'different': 3794,
#  'type': 10973,
#  'ticket': 10655,
#  'why': 11717,
#  'ticketing': 10657,
#  'lines': 6656,
#  'las': 6500,
#  'vegas': 11412,
#  'so': 9885,
#  'unorganized': 11227,
#  'mass': 6995,
#  'craziness': 3430,
#  'half': 5390,
#  'stations': 10094,
#  'unmanned': 11219,
#  'would': 11855,
#  'hire': 5580,
#  'guy': 5360,
#  'who': 11705,
#  'doesn': 3963,
#  'care': 2746,
#  'about': 1387,
#  'safety': 9337,
#  'children': 2949,
#  'remotely': 8989,
#  'acceptable': 1408,
#  'lkfh9hyhw8': 6703,
#  'fingers': 4680,
#  'crossed': 3460,
#  'they': 10587,
#  'more': 7295,
#  'capable': 2730,
#  'getting': 5146,
#  'baggage': 2123,
#  'point': 8347,
#  'gt': 5333,
#  'than': 10532,
#  'airlines': 1590,
#  'when': 11684,
#  'strand': 10166,
#  'someone': 9914,
#  'city': 3002,
#  'without': 11777,
#  'luggage': 6840,
#  'aa': 1317,
#  'earn': 4135,
#  'business': 2610,
#  'couldn': 3376,
#  'funds': 5024,
#  'forfeited': 4885,
#  'show': 9686,
#  'book': 2423,
#  'using': 11350,
#  'those': 10614,
#  'out': 7929,
#  'put': 8656,
#  'sun': 10267,
#  'carry': 2766,
#  'ant_kneee': 1782,
#  'heat': 5497,
#  'wave': 11600,
#  'enjoy': 4283,
#  'warmth': 11576,
#  'bring': 2518,
#  'some': 9911,
#  'home': 5616,
#  'jj': 6239,
#  'sent': 9553,
#  'message': 7120,
#  'let': 6589,
#  'asap': 1917,
#  'embarrassing': 4227,
#  'itself': 6124,
#  'get': 5130,
#  'bad': 2105,
#  'weather': 11618,
#  'isn': 6099,
#  'fault': 4585,
#  'worse': 11838,
#  'give': 5175,
#  'us': 11296,
#  'number': 7705,
#  'instead': 6000,
#  'empty': 4253,
#  'since': 9738,
#  've': 11408,
#  'through': 10634,
#  'reservation': 9065,
#  'system': 10379,
#  'day': 3590,
#  'ridiculous': 9170,
#  'our': 7923,
#  'fleet': 4723,
#  'fleek': 4722,
#  '2uaicfjrms': 555,
#  'way': 11602,
#  'game': 5080,
#  'set': 9580,
#  'match': 7001,
#  'rocks': 9238,
#  'horror': 5669,
#  'flights': 4773,
#  'we': 11610,
#  'spend': 9995,
#  'time': 10676,
#  'family': 4558,
#  'he': 5481,
#  'passes': 8091,
#  'away': 2049,
#  'need': 7477,
#  'track': 10799,
#  'being': 2250,
#  'shipped': 9645,
#  'ph': 8201,
#  'for': 4868,
#  'human': 5724,
#  'automated': 2015,
#  '800': 1162,
#  '335': 607,
#  '2247': 424,
#  'reference': 8899,
#  '261093929756': 485,
#  'tried': 10875,
#  'extremely': 4502,
#  'rude': 9285,
#  'even': 4384,
#  'supervisor': 10287,
#  'asked': 1928,
#  'speak': 9976,
#  'his': 5585,
#  'told': 10739,
#  'missed': 7219,
#  'connection': 3267,
#  'then': 10567,
#  'next': 7529,
#  'lax': 6531,
#  'hawaii': 5468,
#  'paid': 8025,
#  'own': 7988,
#  'rental': 8997,
#  'car': 2741,
#  'go': 5206,
#  'this': 10605,
#  '3rd': 702,
#  'made': 6891,
#  'check': 2919,
#  '1449': 181,
#  'pbi': 8133,
#  'newark': 7518,
#  'stow': 10160,
#  'full': 5015,
#  'costing': 3368,
#  'money': 7274,
#  'aggravation': 1549,
#  'hours': 5689,
#  'patient': 8110,
#  'don': 3977,
#  'back': 2096,
#  'feature': 4602,
#  'pay': 8126,
#  'phone': 8220,
#  'tweet': 10950,
#  'onhold': 7827,
#  'loyalmosaicmember': 6820,
#  'virginamerica': 11469,
#  'fine': 4677,
#  'done': 3981,
#  'purchase': 8644,
#  'try': 10908,
#  'most': 7303,
#  'flying': 4815,
#  '3130': 586,
#  'tonight': 10754,
#  'at': 1963,
#  '20': 362,
#  'position': 8389,
#  '42': 747,
#  'overbooked': 7954,
#  'funeral': 5025,
#  'attend': 1980,
#  '3056': 573,
#  'only': 7833,
#  'hour': 5686,
#  'long': 6761,
#  'best': 2275,
#  'ever': 4392,
#  'had': 5380,
#  'kudos': 6449,
#  'crew': 3443,
#  'general': 5111,
#  'problem': 8530,
#  'laptop': 6495,
#  'plz': 8338,
#  'help': 5516,
#  'win': 11743,
#  'bid': 2309,
#  'upgrade': 11277,
#  '27': 490,
#  'sea': 9481,
#  '1249': 137,
#  'happened': 5419,
#  'courtesy': 3397,
#  'phn': 8217,
#  'diff': 3791,
#  'yes': 11960,
#  'got': 5248,
#  'gate': 5092,
#  'specifically': 9984,
#  'if': 5795,
#  'there': 10572,
#  'any': 1793,
#  'other': 7913,
#  'seats': 9496,
#  'very': 11434,
#  'discouraging': 3850,
#  'walk': 11555,
#  'past': 8098,
#  '37d': 655,
#  'leopolds_ic': 6584,
#  'friend': 4963,
#  'picture': 8241,
#  'phillip': 8211,
#  'heller': 5513,
#  'jfk': 6227,
#  'ifc': 5796,
#  'said': 9344,
#  'delicious': 3670,
#  'announcement': 1762,
#  'states': 10089,
#  'due': 4084,
#  'maintenance': 6911,
#  'yet': 11964,
#  'app': 1821,
#  'says': 9411,
#  'arriving': 1910,
#  'aircraft': 1577,
#  'truth': 10903,
#  'unfriendly': 11180,
#  'll': 6704,
#  'calling': 2693,
#  'soon': 9926,
#  'tomorrow': 10745,
#  'like': 6637,
#  'shows': 9691,
#  'good': 5228,
#  'option': 7870,
#  'please': 8316,
#  'explain': 4482,
#  'reps': 9032,
#  'ignoring': 5808,
#  'technical': 10470,
#  'issue': 6102,
#  'passing': 8092,
#  'buck': 2562,
#  'model': 7259,
#  'lucky': 6837,
#  'limited': 6648,
#  'still': 10124,
#  'board': 2401,
#  'exit': 4452,
#  'row': 9266,
#  'disappointed': 3836,
#  'lack': 6468,
#  'compassion': 3183,
#  'services': 9577,
#  'dept': 3717,
#  'nearly': 7474,
#  'beg': 2236,
#  '838': 1178,
#  'leaving': 6561,
#  'mechanical': 7060,
#  'lodging': 6738,
#  'voucher': 11504,
#  'meals': 7045,
#  'st': 10050,
#  'thomas': 10612,
#  'die': 3786,
#  'amazing': 1685,
#  'hear': 5492,
#  'songs': 9923,
#  'real': 8811,
#  'added': 1473,
#  'seven': 9587,
#  'far': 4566,
#  'take': 10414,
#  'odds': 7765,
#  'carousel': 2759,
#  'kc': 6342,
#  'notcool': 7660,
#  'part': 8064,
#  'drop': 4059,
#  'inserted': 5984,
#  'cc': 2818,
#  'didn': 3784,
#  'print': 8510,
#  'agent': 1544,
#  'standing': 10070,
#  'front': 4978,
#  'f5r3zz': 4513,
#  'work': 11817,
#  'comm': 3152,
#  'skills': 9782,
#  'hate': 5455,
#  'agents': 1545,
#  'phx': 8229,
#  'dfw': 3769,
#  'standby': 10068,
#  'week': 11631,
#  'trip': 10877,
#  'thanks': 10537,
#  'making': 6920,
#  'choice': 2965,
#  'easy': 4150,
#  'disunited': 3912,
#  'servicefail': 9576,
#  '1680': 244,
#  'super': 10280,
#  'smooth': 9854,
#  'landing': 6486,
#  'nicely': 7545,
#  'responding': 9085,
#  'quickly': 8714,
#  'helpful': 5521,
#  'tool': 10759,
#  'dustyob': 4106,
#  'functionality': 5021,
#  'though': 10615,
#  'click': 3041,
#  'action': 1452,
#  'seriously': 9568,
#  '45': 792,
#  'bhm': 2303,
#  'worstairlineever': 11842,
#  'question': 8707,
#  'provide': 8599,
#  'address': 1479,
#  'nashville': 7441,
#  'today': 10728,
#  'kidding': 6385,
#  're': 8793,
#  'frustrated': 4988,
#  'same': 9359,
#  'also': 1665,
#  '5903': 958,
#  'stranded': 10167,
#  'tarmac': 10439,
#  'chicago': 2942,
#  'gates': 5093,
#  'available': 2025,
#  'hot': 5676,
#  'lpalumbo': 6822,
#  'xijifymvqp': 11915,
#  'houston': 5692,
#  'hub': 5715,
#  'employee': 4248,
#  'pa': 8005,
#  'before': 2235,
#  'oops': 7844,
#  'uld0hwfkfo': 11111,
#  'definitely': 3648,
#  'friends': 4969,
#  'boston': 2447,
#  'stuck': 10206,
#  'denver': 3695,
#  'her': 5534,
#  'name': 7421,
#  'jane': 6166,
#  'rncahill': 9204,
#  'contact': 3296,
#  'sucks': 10244,
#  'passengers': 8089,
#  'room': 9252,
#  'checking': 2922,
#  'delayed': 3662,
#  'mine': 7186,
#  'deliver': 3675,
#  'claim': 3007,
#  'closed': 3052,
#  'seat': 9489,
#  'assignment': 1943,
#  'policy': 8357,
#  'choose': 2967,
#  'two': 10965,
#  'weeks': 11636,
#  'flightr': 4771,
#  'favorite': 4591,
#  'find': 4674,
#  'cheap': 2911,
#  'dc': 3595,
#  'louis': 6797,
#  'prices': 8500,
#  'went': 11652,
#  'crazy': 3431,
#  'april': 1862,
#  'weekends': 11633,
#  'legal': 6568,
#  'department': 3703,
#  'start': 10078,
#  'running': 9304,
#  'social': 9891,
#  'media': 7066,
#  'channels': 2878,
#  'joke': 6264,
#  'stop': 10149,
#  'losing': 6784,
#  'ods1819': 7767,
#  'aren': 1881,
#  'glad': 5183,
#  'bet': 2283,
#  'these': 10577,
#  'birds': 2328,
#  'wish': 11770,
#  'flown': 4789,
#  'south': 9952,
#  'winter': 11759,
#  'hepknpuzwu': 5533,
#  'via': 11443,
#  'fb': 4593,
#  'messages': 7122,
#  'twitter': 10962,
#  'dm': 3937,
#  'text': 10519,
#  'ceo': 2843,
#  'battles': 2180,
#  'appease': 1830,
#  'wall': 11559,
#  'street': 10180,
#  'uy28d1uegx': 11369,
#  'vjfv7ksgcq': 11482,
#  'especially': 4354,
#  'mom': 7265,
#  'ichangedyourdiaper': 5773,
#  'hopefully': 5648,
#  'easily': 4146,
#  'resolved': 9075,
#  '98': 1261,
#  'den': 3691,
#  '2hrs': 534,
#  'idea': 5779,
#  'might': 7162,
#  'again': 1537,
#  'forecast': 4875,
#  'etc': 4366,
#  'reservations': 9066,
#  'refunded': 8915,
#  'nothing': 7669,
#  'displayed': 3884,
#  'over': 7950,
#  'weekend': 11632,
#  'during': 4104,
#  'storm': 10157,
#  'dropped': 4060,
#  'layovers': 6535,
#  'him': 5572,
#  'all': 1637,
#  'based': 2166,
#  'behavior': 2246,
#  'cot': 3372,
#  'seem': 9520,
#  'enough': 4287,
#  'lol': 6754,
#  'much': 7347,
#  'helps': 5526,
#  'ton': 10749,
#  'whoever': 11707,
#  'acct': 1432,
#  'deserves': 3729,
#  'handshake': 5406,
#  'chocolate': 2964,
#  'problemsolvers': 8532,
#  'reply': 9017,
#  'note': 7661,
#  'pilot': 8252,
#  'nailed': 7419,
#  'happy': 5425,
#  'anniversary': 1756,
#  'hard': 5437,
#  'believe': 2253,
#  '15': 187,
#  'young': 11980,
#  'submitted': 10226,
#  'status': 10096,
#  'heard': 5493,
#  'im': 5826,
#  'assist': 1945,
#  'completely': 3208,
#  'ripped': 9187,
#  'airways': 1603,
#  'never': 7506,
#  'fly': 4803,
#  'contacting': 3298,
#  'local': 6726,
#  'news': 7525,
#  'happens': 5421,
#  'able': 1383,
#  'rep': 9001,
#  'hf8ajz4ffl': 5548,
#  'livvyports16': 6695,
#  'became': 2222,
#  'bcuz': 2192,
#  'imaginedragons': 5829,
#  'woman': 11798,
#  'gets': 5144,
#  'holds': 5607,
#  'bulkhead': 2580,
#  'earlybird': 4133,
#  'thx': 10647,
#  'reflight': 8905,
#  'necessary': 7475,
#  'afford': 1527,
#  'deal': 3609,
#  'kind': 6394,
#  'unprofessionalism': 11234,
#  'however': 5696,
#  'credit': 3439,
#  'requesting': 9039,
#  'charity': 2896,
#  'donation': 3980,
#  'thankyou': 10543,
#  'down': 4009,
#  'oversold': 7976,
#  'earlybirdmeansnothing': 4134,
#  '1230': 132,
#  'follows': 4858,
#  'threat': 10623,
#  'sue': 10246,
#  'because': 2223,
#  'defend': 3643,
#  'free': 4940,
#  'fair': 4542,
#  'usually': 11353,
#  'rant': 8770,
#  'listening': 6673,
#  'empathy': 4244,
#  'story': 10159,
#  'reaching': 8798,
#  'pick': 8235,
#  'coming': 3151,
#  'nopq5xisbs': 7637,
#  'flyingitforward': 4817,
#  'port': 8379,
#  'au': 1996,
#  'prince': 8506,
#  'haiti': 5388,
#  'earthquake': 4142,
#  'relief': 8968,
#  'efforts': 4182,
#  'lots': 6792,
#  'forever': 4881,
#  'first': 4692,
#  '2nd': 543,
#  'air': 1571,
#  'eis9hcnpro': 4189,
#  '1st': 352,
#  'failure': 4540,
#  'hrs': 5706,
#  'runway': 9307,
#  '13': 152,
#  'resolution': 9073,
#  'needed': 7479,
#  'complaint': 3204,
#  'ticketed': 10656,
#  'passenger': 8087,
#  'scheduled': 9438,
#  'leave': 6559,
#  'traveling': 10840,
#  'kids': 6386,
#  'ages': 1546,
#  'domestic': 3973,
#  'birth': 2330,
#  'certificates': 2848,
#  'airport': 1595,
#  'worst': 11839,
#  'experience': 4473,
#  'together': 10733,
#  'anna': 1753,
#  'palm': 8039,
#  'springs': 10028,
#  '19': 308,
#  'medal': 7064,
#  'handled': 5400,
#  'ppl': 8419,
#  'missing': 7225,
#  'pro': 8523,
#  'great': 5286,
#  'cabin': 2662,
#  'morning': 7297,
#  '578': 949,
#  'smile': 9846,
#  'staff': 10055,
#  'signs': 9721,
#  'company': 3177,
#  '4609': 815,
#  'landed': 6485,
#  'ago': 1553,
#  'single': 9746,
#  'really': 8819,
#  'stepping': 10114,
#  'vqtyza6mzu': 11511,
#  'thru': 10640,
#  'sure': 10302,
#  'learning': 6553,
#  'awesome': 2053,
#  'management': 6935,
#  'marketing': 6974,
#  'class': 3018,
#  'keep': 6352,
#  'sxu': 10363,
#  'phd_mama_': 8203,
#  'screwed': 9468,
#  'assigned': 1942,
#  'new': 7517,
#  'changed': 2873,
#  'original': 7895,
#  '728': 1098,
#  'stated': 10087,
#  'issues': 6104,
#  'around': 1899,
#  'close': 3051,
#  'door': 3995,
#  'strange': 10171,
#  'hearing': 5494,
#  'periods': 8175,
#  'axryeiwzh0': 2064,
#  'vuelo24': 11517,
#  'es': 4346,
#  'vuelos24': 11518,
#  'sell': 9541,
#  'mad': 6887,
#  'nyc': 7725,
#  'trusted': 10902,
#  'webs': 11623,
#  'scam': 9419,
#  'called': 2690,
#  'person': 8182,
#  'weird': 11641,
#  'mileage': 7172,
#  '666': 1042,
#  'cheers': 2929,
#  'tail': 10408,
#  'n598jb': 7397,
#  'n615jb': 7399,
#  'red': 8876,
#  'sox': 9966,
#  'livery': 6689,
#  'share': 9622,
#  'talk': 10423,
#  'send': 9546,
#  'them': 10563,
#  'horrendous': 5661,
#  'off': 7770,
#  'planes': 8291,
#  'phil': 8207,
#  '10': 46,
#  'captain': 2736,
#  'info': 5950,
#  'wtf': 11885,
#  'wanted': 11571,
#  'anytime': 1802,
#  '11': 90,
#  '50': 873,
#  '00': 0,
#  '46mins': 824,
#  'answers': 1778,
#  'sorry': 9934,
#  'dice': 3781,
#  'transfer': 10814,
#  'stewardess': 10119,
#  'disinfectant': 3867,
#  'wipe': 11765,
#  'trash': 10832,
#  'hands': 5405,
#  'badservice': 2117,
#  'request': 9037,
#  '3001408092': 566,
#  'flighted': 4757,
#  '2222': 420,
#  'phl': 8214,
#  'assistance': 1946,
#  'love': 6802,
#  'austin': 2009,
#  'excellent': 4421,
#  'mex': 7132,
#  'york': 11975,
#  'tuesday': 10927,
#  'unacceptable': 11120,
#  'its': 6121,
#  'stressful': 10185,
#  'wilmington': 11742,
#  'miss': 7218,
#  'charlotte': 2900,
#  'figure': 4656,
#  'arrive': 1907,
#  'motions': 7307,
#  'shortly': 9668,
#  'yesterday': 11963,
#  'wonder': 11801,
#  'attendants': 1982,
#  'dmed': 3941,
#  '460': 814,
#  'departure': 3706,
#  'keeps': 6362,
#  'changing': 2876,
#  'nvr': 7715,
#  'con': 3224,
#  'bc': 2190,
#  'coffeemaker': 3106,
#  'ft1892': 4996,
#  'father': 4582,
#  'be4': 2204,
#  'coma': 3131,
#  'epic': 4317,
#  'fail': 4533,
#  'reagan': 8809,
#  'jetway': 6222,
#  'mins': 7193,
#  'greatest': 5289,
#  'truebluepoints': 10898,
#  'jetbluemember': 6214,
#  'less': 6586,
#  'driving': 4057,
#  'aspen': 1933,
#  'snowstorm': 9881,
#  'teams': 10465,
#  'bogota': 2411,
#  'wallet': 11560,
#  'fun': 5018,
#  'waiving': 11551,
#  'fees': 4623,
#  'snow': 9874,
#  'iad': 5762,
#  'under': 11150,
#  'warning': 11578,
#  'hi': 5554,
#  'guys': 5362,
#  'enquires': 4289,
#  'david': 3587,
#  'possible': 8395,
#  'swa': 10328,
#  'cut': 3522,
#  'doing': 3968,
#  'lousy': 6801,
#  'run': 9300,
#  'connect': 3262,
#  'zip': 12038,
#  'second': 9500,
#  'into': 6051,
#  'typical': 10974,
#  'sending': 9547,
#  'posting': 8400,
#  'complete': 3206,
#  'details': 3754,
#  'circumstances': 2997,
#  'surrounding': 10316,
#  'matter': 7005,
#  'ashamed': 1920,
#  'luck': 6835,
#  'dealing': 3610,
#  'horrible': 5662,
#  'follow': 4853,
#  'bussines': 2614,
#  'ua1069': 10989,
#  'sunglasses': 10271,
#  '26f': 488,
#  'unitedairlines': 11196,
#  'usual': 11352,
#  'cleanliness': 3032,
#  'smells': 9841,
#  'bit': 2335,
#  'satisfied': 9389,
#  'traveler': 10837,
#  'thing': 10594,
#  '30pm': 581,
#  'many': 6952,
#  'train': 10806,
#  'manners': 6946,
#  'decency': 3623,
#  'connecting': 3266,
#  'rather': 8783,
#  'hotel': 5677,
#  'reimbursement': 8945,
#  'night': 7555,
#  'stay': 10098,
#  'dominican': 3975,
#  'sugafly': 10251,
#  'ok': 7794,
#  'delete': 3666,
#  '_lucy_may': 1296,
#  'surely': 10304,
#  'better': 2285,
#  'feedback': 4615,
#  'unless': 11212,
#  'something': 9915,
#  'hide': 5560,
#  '919': 1245,
#  '24h': 461,
#  'newyork': 7528,
#  'viracopos': 11466,
#  'americanairlines': 1697,
#  '3fhes0lpmu': 688,
#  'waited': 11539,
#  'disconnect': 3843,
#  'checked': 2920,
#  'rebecca': 8830,
#  'levi': 6602,
#  'hiltonworldwide': 5571,
#  'caravannyc': 2742,
#  'maysvillenyc': 7018,
#  'join': 6262,
#  'tourist': 10785,
#  'egaejtrglb': 4183,
#  'concerns': 3229,
#  'were': 11654,
#  'addressed': 1480,
#  'umm': 11114,
#  'reason': 8824,
#  'definitive': 3650,
#  'flew': 4724,
#  'improve': 5853,
#  'lose': 6780,
#  'customers': 3512,
#  '654': 1038,
#  'sitting': 9760,
#  'delays': 3665,
#  'employees': 4250,
#  'load': 6716,
#  ...}

# %%
X_dtm.shape
# Out:
# (9808, 12056)

# %%
vect = CountVectorizer()

def tokenize_test(vect):
    X_dtm = vect.fit_transform(X_train)
    print('Features: ', X_dtm.shape[1])
    rf = RandomForestClassifier()
    print(pd.Series(cross_val_score(rf, X_dtm, y_train, cv=10)).describe())

# %%
tokenize_test(vect)
# Out:
# Features:  12056
# count    10.000000
# mean      0.749182
# std       0.009219
# min       0.734694
# 25%       0.743309
# 50%       0.748216
# 75%       0.753313
# max       0.764526
# dtype: float64

# %% [markdown]
# ### Punto 2 - Eliminación de Stopwords
#
# En la celda 2 creen un modelo de random forest con la libreria sklearn que prediga el sentimiento de los tweets usando los set de entrenamiento y test definidos anteriormente. Usen la función CountVectorizer, **eliminen stopwords** y presenten el desempeño del modelo con la métrica del acurracy.
#
# Recuerden que el preprocesamiento que se haga sobre los datos de entrenamiento  (*.fit_transform()*) deben ser aplicado al set de test (*.transform()*).

# %%
# Celda 2
vect = CountVectorizer(stop_words='english', max_features=100)
tokenize_test(vect)
# Out:
# Features:  100
# count    10.000000
# mean      0.688822
# std       0.012890
# min       0.670408
# 25%       0.678644
# 50%       0.688583
# 75%       0.697248
# max       0.708461
# dtype: float64

# %% [markdown]
# ### Punto 3 - Lematización con verbos
#
# En la celda 3 creen un modelo de random forest con la libreria sklearn que prediga el sentimiento de los tweets usando los set de entrenamiento y test definidos anteriormente. Usen la función CountVectorizer, **lematizen el texto con verbos** y presenten el desempeño del modelo con la métrica del acurracy.
#
# Recuerden que el preprocesamiento que se haga sobre los datos de entrenamiento  (*.fit_transform()*) deben ser aplicado al set de test (*.transform()*).

# %%
# Celda 3
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\luisa\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping corpora\wordnet.zip.
# True

# %%
words = list(vect.vocabulary_.keys())
print([wordnet_lemmatizer.lemmatize(word) for word in words])
print([wordnet_lemmatizer.lemmatize(word,pos='v') for word in words])

def split_into_lemmas(text):
    text = text.lower()
    words = text.split()
    return [wordnet_lemmatizer.lemmatize(word) for word in words]
# Out:
# ['jetblue', 'americanair', 'delay', 'southwestair', 'flight', 'http', 'usairways', 'airline', 'know', 'united', 'want', 'plane', 'cancelled', 'flightled', 'going', 'trying', 'make', 'late', 'did', 'email', 'bag', 'boarding', 'thank', 'right', 'amp', 'just', 'lost', 'customer', 'service', 'waiting', 'min', 'hold', 'bag', 'online', 'response', 'change', 'problem', 'ticket', 'getting', 'baggage', 'luggage', 'aa', 'home', 'let', 'weather', 'number', 've', 'day', 'way', 'flight', 'time', 'need', 'told', 'check', 'hour', 'don', 'phone', 'virginamerica', 'flying', 'hour', 'long', 'crew', 'help', 'yes', 'got', 'gate', 'seat', 'jfk', 'said', 'll', 'tomorrow', 'like', 'good', 'didn', 'agent', 'work', 'trip', 'thanks', 'today', 'passenger', 'delayed', 'seat', 'dm', 'fly', 'hr', 'airport', 'worst', 'experience', 'great', 'really', 'new', 'flighted', 'love', 'guy', 'customer', 'people', 'minute', 'travel', 'wait', 'day']
# ['jetblue', 'americanair', 'delay', 'southwestair', 'flight', 'http', 'usairways', 'airline', 'know', 'unite', 'want', 'plane', 'cancel', 'flightled', 'go', 'try', 'make', 'late', 'do', 'email', 'bag', 'board', 'thank', 'right', 'amp', 'just', 'lose', 'customer', 'service', 'wait', 'min', 'hold', 'bag', 'online', 'response', 'change', 'problems', 'ticket', 'get', 'baggage', 'luggage', 'aa', 'home', 'let', 'weather', 'number', 've', 'day', 'way', 'flight', 'time', 'need', 'tell', 'check', 'hours', 'don', 'phone', 'virginamerica', 'fly', 'hour', 'long', 'crew', 'help', 'yes', 'get', 'gate', 'seat', 'jfk', 'say', 'll', 'tomorrow', 'like', 'good', 'didn', 'agent', 'work', 'trip', 'thank', 'today', 'passengers', 'delay', 'seat', 'dm', 'fly', 'hrs', 'airport', 'worst', 'experience', 'great', 'really', 'new', 'flight', 'love', 'guy', 'customers', 'people', 'minutes', 'travel', 'wait', 'days']

# %%
vect_lemas = CountVectorizer(analyzer=split_into_lemmas)
tokenize_test(vect_lemas)
# Out:
# Features:  20084
# count    10.000000
# mean      0.734296
# std       0.013827
# min       0.717635
# 25%       0.724956
# 50%       0.734455
# 75%       0.739551
# max       0.762487
# dtype: float64

# %% [markdown]
# ### Punto 4 - Multiples técnicas
#
# En la celda 4 creen un modelo de random forest con la libreria sklearn que prediga el sentimiento de los tweets usando los set de entrenamiento y test definidos anteriormente. Usen la función **CountVectorizer, eliminen stopwords, lematizen el texto con verbos** y presenten el desempeño del modelo con la métrica del acurracy.
#
# Recuerden que el preprocesamiento que se haga sobre los datos de entrenamiento  (*.fit_transform()*) deben ser aplicado al set de test (*.transform()*).

# %%
# Celda 4

# %% [markdown]
# ### Punto 5 - Comparación y análisis de resultados
#
# En la celda 5 comparen los resultados obtenidos de los diferentes modelos (random forest) y comenten las ventajas del mejor modelo y las desventajas del modelo con el menor desempeño.

# %%
# Celda 5
